# %% [markdown]
# ### Evaluating the impact of variable readnoise in different chips ###
#
# As chips are being delivered, they are being tested to evaluate their readnoise limits. Different chips show different behavior. This notebook evaluates the impact of these different readnoise levels, as well as evaluating the overall impact considering the distribution of readnoise/chips.

# %%
import numpy as np
import pandas as pd
# import rubin_sim.phot_utils as phot_utils
import syseng_throughputs as st

# %%
pd.set_option('display.precision', 3)

# %%
# Read bandpass information.
defaultDirs = st.setDefaultDirs()
addLosses = True
atmosphere = st.readAtmosphere(defaultDirs['atmosphere'], atmosFile='atmos_10_aerosol.dat')
hardware, system = st.buildHardwareAndSystem(defaultDirs, addLosses, atmosphereOverride=atmosphere)
# Out:
# /Users/lynnej/lsst_repos/rubin_sim/rubin_sim/phot_utils/bandpass.py:67: UserWarning: Wavelength sampling of 1.0 nm is > 0.2 nm, this may not work well with a Sed object. Consider resampling with resample_bandpass method.
#   warnings.warn(
# /Users/lynnej/lsst_repos/rubin_sim/rubin_sim/phot_utils/bandpass.py:67: UserWarning: Wavelength sampling of 800.0 nm is > 0.2 nm, this may not work well with a Sed object. Consider resampling with resample_bandpass method.
#   warnings.warn(

# %%
# Standard LSST visits, standard LSST readnoise and 1 visit = 15s x 2exp
v_standard = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_standard
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   2.0     15.0     0.92     0.808  22.991     64.018  26.814  0.030  0.047
# g   2.0     15.0     0.87     0.767  22.264    423.326  28.417  0.131  0.160
# r   2.0     15.0     0.83     0.734  21.199    844.831  28.192  0.106  0.120
# i   2.0     15.0     0.80     0.710  20.474   1248.344  27.921  0.083  0.091
# z   2.0     15.0     0.78     0.693  19.595   1890.565  27.519  0.057  0.061
# y   2.0     15.0     0.76     0.677  18.597   2410.428  26.685  0.027  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.495  0.038  22.994         0.659       0.427  23.692       531.870
# g  0.215  0.039  24.451         0.172       0.091  24.847       803.955
# r  0.127  0.039  24.466         0.093       0.046  24.381      1003.147
# i  0.096  0.039  24.377         0.065       0.031  23.969      1142.755
# z  0.069  0.039  24.213         0.044       0.020  23.393      1342.078
# y  0.169  0.039  23.756         0.035       0.016  22.465      1462.863
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
# Standard LSST readnoise but 1 visit = 30s x 1exp
v_double = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_double
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   1.0     30.0     0.92     0.808  22.991     64.018  26.814  0.030  0.047
# g   1.0     30.0     0.87     0.767  22.264    423.326  28.417  0.131  0.160
# r   1.0     30.0     0.83     0.734  21.199    844.831  28.192  0.106  0.120
# i   1.0     30.0     0.80     0.710  20.474   1248.344  27.921  0.083  0.091
# z   1.0     30.0     0.78     0.693  19.595   1890.565  27.519  0.057  0.061
# y   1.0     30.0     0.76     0.677  18.597   2410.428  26.685  0.027  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.495  0.038  23.217         0.436       0.265  23.915       433.114
# g  0.215  0.039  24.527         0.096       0.048  24.923       749.649
# r  0.127  0.039  24.509         0.050       0.023  24.424       964.250
# i  0.096  0.039  24.407         0.035       0.015  23.999      1111.265
# z  0.069  0.039  24.233         0.023       0.009  23.413      1316.744
# y  0.169  0.039  23.773         0.018       0.007  22.482      1440.858
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
# Standard LSST readnoise but 1 visit = 50s x 1exp
v_fifty = st.makeM5(hardware, system, exptime=50, nexp=1, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_fifty
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   1.0     50.0     0.92     0.808  22.991    106.697  26.814  0.030  0.047
# g   1.0     50.0     0.87     0.767  22.264    705.543  28.417  0.131  0.160
# r   1.0     50.0     0.83     0.734  21.199   1408.051  28.192  0.106  0.120
# i   1.0     50.0     0.80     0.710  20.474   2080.573  27.921  0.083  0.091
# z   1.0     50.0     0.78     0.693  19.595   3150.942  27.519  0.057  0.061
# y   1.0     50.0     0.76     0.677  18.597   4017.381  26.685  0.027  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.495  0.038  23.349         0.315       0.188  24.325       495.067
# g  0.215  0.039  24.565         0.063       0.031  25.238       934.564
# r  0.127  0.039  24.531         0.032       0.015  24.723      1220.490
# i  0.096  0.039  24.423         0.022       0.010  24.292      1414.371
# z  0.069  0.039  24.244         0.015       0.006  23.702      1682.978
# y  0.169  0.039  23.781         0.012       0.004  22.768      1844.986
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
v_standard['m5'].loc['u'], v_double['m5'].loc['u'], v_fifty['m5'].loc['u']
# Out:
# (23.692099908567357, 23.915106567632826, 24.324574888862905)

# %%
# 7e readnoise, 1 visit = 15s x 2exp
v_7_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=7, othernoise=0, darkcurrent=0.2)
# 7e readnoise, 1 visit = 30s x 1 exp
v_7_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=7, othernoise=0, darkcurrent=0.2)

# %%
# 9e readnoise, 1 visit = 15s x 2 exp
v_9_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=9, othernoise=0, darkcurrent=0.2)
# 9e readnoise, 1 visit = 30s x 1 exp                  
v_9_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=9, othernoise=0, darkcurrent=0.2)

# %%
# 13 e readnoise, 1 visit = 15s x 2 exp
v_13_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=13, othernoise=0, darkcurrent=0.2)
# 13e readnoise, 1 visit = 30s x 1 exp
v_13_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=13, othernoise=0, darkcurrent=0.2)

# %%
# 18 e readnoise, 1 visit = 15s x 2 exp
v_18_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=18, othernoise=0, darkcurrent=0.2)
# 18e readnoise, 1 visit = 30s x 1 exp
v_18_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=18, othernoise=0, darkcurrent=0.2)

# %%
cols = ['dCm_infinity']
coln = 'dCm_inf'
m5s = [v_7_15, v_7_30, v_9_15, v_9_30, v_13_15, v_13_30, v_18_15, v_18_30]
names = ['7_15', '7_30', '9_15', '9_30', '13_15', '13_30', '18_15', '18_30']
fullnames = []
for n in names:
    fullnames.append(n + ' ' + coln)
first = True
for x, n in zip(m5s, fullnames):
    tmp = pd.DataFrame(x[cols])
    tmp.columns = [n]
    if first:
        d = tmp
        first = False
    else:
        d = d.join(tmp)
d
# Out:
#    7_15 dCm_inf  7_30 dCm_inf  9_15 dCm_inf  9_30 dCm_inf  13_15 dCm_inf  \
# u         0.505         0.324         0.676         0.449          0.976
# g         0.117         0.065         0.178         0.100          0.318
# r         0.062         0.034         0.097         0.052          0.183
# i         0.043         0.023         0.068         0.036          0.131
# z         0.029         0.015         0.046         0.024          0.090
# y         0.023         0.012         0.036         0.019          0.072
#
#    13_30 dCm_inf  18_15 dCm_inf  18_30 dCm_inf
# u          0.692          1.278          0.957
# g          0.185          0.500          0.308
# r          0.101          0.308          0.177
# i          0.070          0.226          0.126
# z          0.048          0.160          0.087
# y          0.038          0.129          0.069

# %% [markdown]
# ### Impact on dCm_infinity ###

# %%
# Change in dCm_infinity
d.subtract(d['9_15 dCm_inf'], axis=0)
# Out:
#    7_15 dCm_inf  7_30 dCm_inf  9_15 dCm_inf  9_30 dCm_inf  13_15 dCm_inf  \
# u        -0.171        -0.352           0.0        -0.227          0.300
# g        -0.061        -0.113           0.0        -0.079          0.139
# r        -0.035        -0.063           0.0        -0.045          0.086
# i        -0.025        -0.045           0.0        -0.032          0.063
# z        -0.017        -0.030           0.0        -0.022          0.044
# y        -0.014        -0.024           0.0        -0.017          0.036
#
#    13_30 dCm_inf  18_15 dCm_inf  18_30 dCm_inf
# u          0.016          0.602          0.282
# g          0.006          0.321          0.130
# r          0.004          0.210          0.080
# i          0.003          0.159          0.058
# z          0.002          0.114          0.041
# y          0.001          0.093          0.033

# %%
# Latex version for documents
print(d.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & 7_15 dCm_inf & 7_30 dCm_inf & 9_15 dCm_inf & 9_30 dCm_inf & 13_15 dCm_inf & 13_30 dCm_inf & 18_15 dCm_inf & 18_30 dCm_inf \\
# \midrule
# u & 0.505078 & 0.323587 & 0.675780 & 0.448826 & 0.975900 & 0.691537 & 1.277943 & 0.957288 \\
# g & 0.117160 & 0.065118 & 0.178340 & 0.099669 & 0.317699 & 0.184629 & 0.499574 & 0.307842 \\
# r & 0.062181 & 0.033775 & 0.097163 & 0.052494 & 0.183091 & 0.100855 & 0.307503 & 0.176735 \\
# i & 0.042941 & 0.023134 & 0.067763 & 0.036151 & 0.130666 & 0.070409 & 0.226270 & 0.125922 \\
# z & 0.028790 & 0.015416 & 0.045773 & 0.024187 & 0.089899 & 0.047599 & 0.159810 & 0.086518 \\
# y & 0.022729 & 0.012139 & 0.036256 & 0.019079 & 0.071798 & 0.037715 & 0.129226 & 0.069055 \\
# \bottomrule
# \end{tabular}

# %%
cols = ['m5']
coln = 'm5'
m5s = [v_7_15, v_7_30, v_9_15, v_9_30, v_13_15, v_13_30, v_18_15, v_18_30]
names = ['7_15', '7_30', '9_15', '9_30', '13_15', '13_30', '18_15', '18_30']
fullnames = []
for n in names:
    fullnames.append(n + ' ' + coln)
first = True
for x, n in zip(m5s, fullnames):
    tmp = pd.DataFrame(x[cols])
    tmp.columns = [n]
    if first:
        d = tmp
        first = False
    else:
        d = d.join(tmp)
d
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u   23.846   24.028   23.676   23.903    23.375    23.660    23.073    23.394
# g   24.902   24.954   24.841   24.919    24.701    24.834    24.519    24.711
# r   24.412   24.441   24.377   24.422    24.291    24.373    24.167    24.298
# i   23.991   24.011   23.966   23.998    23.903    23.964    23.808    23.908
# z   23.408   23.421   23.391   23.412    23.347    23.389    23.277    23.350
# y   22.477   22.488   22.464   22.481    22.428    22.462    22.371    22.431

# %% [markdown]
# ### Impact on m5 ###

# %%
d.subtract(d['9_15 m5'], axis=0)
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u    0.171    0.352      0.0    0.227    -0.300    -0.016    -0.602    -0.282
# g    0.061    0.113      0.0    0.079    -0.139    -0.006    -0.321    -0.130
# r    0.035    0.063      0.0    0.045    -0.086    -0.004    -0.210    -0.080
# i    0.025    0.045      0.0    0.032    -0.063    -0.003    -0.159    -0.058
# z    0.017    0.030      0.0    0.022    -0.044    -0.002    -0.114    -0.041
# y    0.014    0.024      0.0    0.017    -0.036    -0.001    -0.093    -0.033

# %% [markdown]
# ### Impact on effective time ###

# %%
SRD_time_distribution = {'u': 0.068, 'g': 0.097, 'r': 0.223, 
                         'i': 0.223, 'z': 0.194, 'y': 0.194}
# Fractional change in effective time is proportional to change in m5.
# Longer = better
dtime = np.power(10, 0.8 * (d.subtract(d['9_15 m5'], axis=0)))
dtime
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u    1.369    1.913      1.0    1.519     0.575     0.971     0.330     0.595
# g    1.119    1.232      1.0    1.156     0.774     0.988     0.553     0.788
# r    1.067    1.124      1.0    1.086     0.854     0.993     0.679     0.864
# i    1.047    1.086      1.0    1.060     0.891     0.995     0.747     0.898
# z    1.032    1.058      1.0    1.041     0.922     0.997     0.811     0.928
# y    1.025    1.045      1.0    1.032     0.937     0.997     0.843     0.941

# %% [markdown]
# Account for distribution of readnoise and filters:
# * 50% of the focal plane has 7e read noise
# * 25% of the focal plane has 9e read noise
# * 20% of the focal plane has 13e read noise
# * 5% of the focal plane has 18e read noise

# %%
# Change in time per band (2x15s visits)
dtime_weighted = (0.50 * dtime['7_15 m5']   + 0.25 * dtime['9_15 m5'] 
                  + 0.20 * dtime['13_15 m5'] + 0.05 * dtime['18_15 m5'])
dtime_weighted
# Out:
# u    1.066
# g    0.992
# r    0.988
# i    0.989
# z    0.991
# y    0.992
# dtype: float64

# %%
dtime_total = 0
for f in SRD_time_distribution:
    dtime_total += dtime_weighted[f] * SRD_time_distribution[f]
dtime_total
# Out:
# 0.9942374081031535

# %%
# Change in time per band (1x30s visits)
dtime_weighted = (0.50 * dtime['7_30 m5']   + 0.25 * dtime['9_30 m5'] 
                  + 0.20 * dtime['13_30 m5'] + 0.05 * dtime['18_30 m5'])
dtime_weighted
# Out:
# u    1.560
# g    1.142
# r    1.075
# i    1.052
# z    1.035
# y    1.027
# dtype: float64

# %%
dtime_total = 0
for f in SRD_time_distribution:
    dtime_total += dtime_weighted[f] * SRD_time_distribution[f]
dtime_total
# Out:
# 1.0912053025258084
