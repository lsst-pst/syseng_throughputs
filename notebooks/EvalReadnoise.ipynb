# %% [markdown]
# ### Evaluating the impact of variable readnoise in different chips ###
#
# As chips are being delivered, they are being tested to evaluate their readnoise limits. Different chips show different behavior. This notebook evaluates the impact of these different readnoise levels, as well as evaluating the overall impact considering the distribution of readnoise/chips.

# %%
import numpy as np
import pandas as pd
# import rubin_sim.phot_utils as phot_utils
import syseng_throughputs as st

# %%
pd.set_option('display.precision', 3)

# %%
# Read bandpass information.
defaultDirs = st.setDefaultDirs()
addLosses = True
atmosphere = st.readAtmosphere(defaultDirs['atmosphere'], atmosFile='atmos_10_aerosol.dat')
hardware, system = st.buildHardwareAndSystem(defaultDirs, addLosses, atmosphereOverride=atmosphere)
# Out:
# /Users/lynnej/lsst_repos/rubin_sim/rubin_sim/phot_utils/bandpass.py:100: UserWarning: Wavelength sampling of 1.0 nm is > 0.2 nm, this may not work well with a Sed object. Consider resampling with resample_bandpass method.
#   warnings.warn(
# /Users/lynnej/lsst_repos/rubin_sim/rubin_sim/phot_utils/bandpass.py:100: UserWarning: Wavelength sampling of 800.0 nm is > 0.2 nm, this may not work well with a Sed object. Consider resampling with resample_bandpass method.
#   warnings.warn(

# %%
# Standard LSST visits, standard LSST readnoise and 1 visit = 15s x 2exp
v_standard = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_standard
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   2.0     15.0     0.92     0.808  22.948     73.638  26.911  0.033  0.052
# g   2.0     15.0     0.87     0.767  22.265    420.441  28.411  0.130  0.159
# r   2.0     15.0     0.83     0.734  21.200    834.660  28.179  0.105  0.118
# i   2.0     15.0     0.80     0.710  20.470   1250.952  27.919  0.083  0.091
# z   2.0     15.0     0.78     0.693  19.599   1916.456  27.538  0.058  0.062
# y   2.0     15.0     0.76     0.677  18.598   2368.700  26.667  0.026  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.507  0.038  23.090         0.609       0.388  23.767       542.855
# g  0.216  0.039  24.447         0.173       0.091  24.843       801.999
# r  0.127  0.039  24.459         0.094       0.047  24.374       998.126
# i  0.096  0.039  24.376         0.065       0.031  23.966      1143.800
# z  0.069  0.039  24.223         0.043       0.020  23.405      1350.441
# y  0.169  0.039  23.746         0.035       0.016  22.456      1451.047
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
# Standard LSST readnoise but 1 visit = 30s x 1exp
v_double = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_double
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   1.0     30.0     0.92     0.808  22.948     73.638  26.911  0.033  0.052
# g   1.0     30.0     0.87     0.767  22.265    420.441  28.411  0.130  0.159
# r   1.0     30.0     0.83     0.734  21.200    834.660  28.179  0.105  0.118
# i   1.0     30.0     0.80     0.710  20.470   1250.952  27.919  0.083  0.091
# z   1.0     30.0     0.78     0.693  19.599   1916.456  27.538  0.058  0.062
# y   1.0     30.0     0.76     0.677  18.598   2368.700  26.667  0.026  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.507  0.038  23.302         0.397       0.237  23.979       446.606
# g  0.216  0.039  24.523         0.097       0.048  24.919       747.549
# r  0.127  0.039  24.502         0.051       0.024  24.417       959.022
# i  0.096  0.039  24.406         0.035       0.015  23.997      1112.340
# z  0.069  0.039  24.243         0.023       0.009  23.425      1325.268
# y  0.169  0.039  23.763         0.019       0.007  22.472      1428.858
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
# Standard LSST readnoise but 1 visit = 50s x 1exp
v_fifty = st.makeM5(hardware, system, exptime=50, nexp=1, readnoise=8.8, othernoise=0, darkcurrent=0.2)
v_fifty
# Out:
#    nexp  exptime  FWHMeff  FWHMgeom  skyMag  skyCounts    Zp_t     Tb     Sb  \
# u   1.0     50.0     0.92     0.808  22.948    122.731  26.911  0.033  0.052
# g   1.0     50.0     0.87     0.767  22.265    700.736  28.411  0.130  0.159
# r   1.0     50.0     0.83     0.734  21.200   1391.100  28.179  0.105  0.118
# i   1.0     50.0     0.80     0.710  20.470   2084.919  27.919  0.083  0.091
# z   1.0     50.0     0.78     0.693  19.599   3194.093  27.538  0.058  0.062
# y   1.0     50.0     0.76     0.677  18.598   3947.833  26.667  0.026  0.031
#
#     kAtm  gamma      Cm  dCm_infinity  dCm_double      m5  sourceCounts  \
# u  0.507  0.038  23.425         0.284       0.167  24.380       514.587
# g  0.216  0.039  24.561         0.063       0.032  25.235       931.765
# r  0.127  0.039  24.524         0.033       0.015  24.716      1213.625
# i  0.096  0.039  24.422         0.022       0.010  24.289      1415.776
# z  0.069  0.039  24.254         0.015       0.006  23.713      1694.070
# y  0.169  0.039  23.772         0.012       0.004  22.759      1829.397
#
#    m5_fid  m5_min
# u    23.9    23.4
# g    25.0    24.6
# r    24.7    24.3
# i    24.0    23.6
# z    23.3    22.9
# y    22.1    21.7

# %%
v_standard['m5'].loc['u'], v_double['m5'].loc['u'], v_fifty['m5'].loc['u']
# Out:
# (23.7673963227186, 23.979294175023753, 24.380082422369973)

# %%
# 7e readnoise, 1 visit = 15s x 2exp
v_7_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=7, othernoise=0, darkcurrent=0.2)
# 7e readnoise, 1 visit = 30s x 1 exp
v_7_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=7, othernoise=0, darkcurrent=0.2)

# %%
# 9e readnoise, 1 visit = 15s x 2 exp
v_9_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=9, othernoise=0, darkcurrent=0.2)
# 9e readnoise, 1 visit = 30s x 1 exp                  
v_9_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=9, othernoise=0, darkcurrent=0.2)

# %%
# 13 e readnoise, 1 visit = 15s x 2 exp
v_13_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=13, othernoise=0, darkcurrent=0.2)
# 13e readnoise, 1 visit = 30s x 1 exp
v_13_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=13, othernoise=0, darkcurrent=0.2)

# %%
# 18 e readnoise, 1 visit = 15s x 2 exp
v_18_15 = st.makeM5(hardware, system, exptime=15, nexp=2, readnoise=18, othernoise=0, darkcurrent=0.2)
# 18e readnoise, 1 visit = 30s x 1 exp
v_18_30 = st.makeM5(hardware, system, exptime=30, nexp=1, readnoise=18, othernoise=0, darkcurrent=0.2)

# %%
cols = ['dCm_infinity']
coln = 'dCm_inf'
m5s = [v_7_15, v_7_30, v_9_15, v_9_30, v_13_15, v_13_30, v_18_15, v_18_30]
names = ['7_15', '7_30', '9_15', '9_30', '13_15', '13_30', '18_15', '18_30']
fullnames = []
for n in names:
    fullnames.append(n + ' ' + coln)
first = True
for x, n in zip(m5s, fullnames):
    tmp = pd.DataFrame(x[cols])
    tmp.columns = [n]
    if first:
        d = tmp
        first = False
    else:
        d = d.join(tmp)
d
# Out:
#    7_15 dCm_inf  7_30 dCm_inf  9_15 dCm_inf  9_30 dCm_inf  13_15 dCm_inf  \
# u         0.462         0.292         0.625         0.409          0.916
# g         0.118         0.066         0.179         0.100          0.319
# r         0.063         0.034         0.098         0.053          0.185
# i         0.043         0.023         0.068         0.036          0.130
# z         0.028         0.015         0.045         0.024          0.089
# y         0.023         0.012         0.037         0.019          0.073
#
#    13_30 dCm_inf  18_15 dCm_inf  18_30 dCm_inf
# u          0.640          1.212          0.897
# g          0.186          0.502          0.309
# r          0.102          0.310          0.179
# i          0.070          0.226          0.126
# z          0.047          0.158          0.085
# y          0.038          0.131          0.070

# %% [markdown]
# ### Impact on dCm_infinity ###

# %%
# Change in dCm_infinity
d.subtract(d['9_15 dCm_inf'], axis=0)
# Out:
#    7_15 dCm_inf  7_30 dCm_inf  9_15 dCm_inf  9_30 dCm_inf  13_15 dCm_inf  \
# u        -0.163        -0.333           0.0        -0.216          0.291
# g        -0.061        -0.114           0.0        -0.079          0.140
# r        -0.035        -0.064           0.0        -0.045          0.087
# i        -0.025        -0.045           0.0        -0.032          0.063
# z        -0.017        -0.030           0.0        -0.021          0.044
# y        -0.014        -0.025           0.0        -0.017          0.036
#
#    13_30 dCm_inf  18_15 dCm_inf  18_30 dCm_inf
# u          0.015          0.588          0.273
# g          0.006          0.322          0.130
# r          0.004          0.212          0.080
# i          0.003          0.158          0.058
# z          0.002          0.113          0.040
# y          0.001          0.094          0.033

# %%
# Latex version for documents
print(d.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & 7_15 dCm_inf & 7_30 dCm_inf & 9_15 dCm_inf & 9_30 dCm_inf & 13_15 dCm_inf & 13_30 dCm_inf & 18_15 dCm_inf & 18_30 dCm_inf \\
# \midrule
# u & 0.461781 & 0.291722 & 0.624625 & 0.408688 & 0.915633 & 0.639770 & 1.212379 & 0.897453 \\
# g & 0.117875 & 0.065534 & 0.179370 & 0.100286 & 0.319326 & 0.185689 & 0.501778 & 0.309431 \\
# r & 0.062891 & 0.034171 & 0.098238 & 0.053099 & 0.184965 & 0.101967 & 0.310330 & 0.178554 \\
# i & 0.042855 & 0.023087 & 0.067631 & 0.036079 & 0.130426 & 0.070273 & 0.225887 & 0.125690 \\
# z & 0.028413 & 0.015212 & 0.045183 & 0.023869 & 0.088785 & 0.046986 & 0.157947 & 0.085442 \\
# y & 0.023119 & 0.012350 & 0.036870 & 0.019407 & 0.072976 & 0.038353 & 0.131237 & 0.070190 \\
# \bottomrule
# \end{tabular}

# %%
cols = ['m5']
coln = 'm5'
m5s = [v_7_15, v_7_30, v_9_15, v_9_30, v_13_15, v_13_30, v_18_15, v_18_30]
names = ['7_15', '7_30', '9_15', '9_30', '13_15', '13_30', '18_15', '18_30']
fullnames = []
for n in names:
    fullnames.append(n + ' ' + coln)
first = True
for x, n in zip(m5s, fullnames):
    tmp = pd.DataFrame(x[cols])
    tmp.columns = [n]
    if first:
        d = tmp
        first = False
    else:
        d = d.join(tmp)
d
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u   23.914   24.084   23.752   23.967    23.461    23.736    23.164    23.479
# g   24.898   24.950   24.837   24.916    24.697    24.830    24.514    24.707
# r   24.405   24.434   24.370   24.415    24.283    24.366    24.158    24.290
# i   23.988   24.008   23.964   23.995    23.901    23.961    23.805    23.906
# z   23.419   23.433   23.403   23.424    23.359    23.401    23.290    23.362
# y   22.468   22.479   22.454   22.471    22.418    22.453    22.360    22.421

# %% [markdown]
# ### Impact on m5 ###

# %%
d.subtract(d['9_15 m5'], axis=0)
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u    0.163    0.333      0.0    0.216    -0.291    -0.015    -0.588    -0.273
# g    0.061    0.114      0.0    0.079    -0.140    -0.006    -0.322    -0.130
# r    0.035    0.064      0.0    0.045    -0.087    -0.004    -0.212    -0.080
# i    0.025    0.045      0.0    0.032    -0.063    -0.003    -0.158    -0.058
# z    0.017    0.030      0.0    0.021    -0.044    -0.002    -0.113    -0.040
# y    0.014    0.025      0.0    0.017    -0.036    -0.001    -0.094    -0.033

# %% [markdown]
# ### Impact on effective time ###

# %%
SRD_time_distribution = {'u': 0.068, 'g': 0.097, 'r': 0.223, 
                         'i': 0.223, 'z': 0.194, 'y': 0.194}
# Fractional change in effective time is proportional to change in m5.
# Longer = better
dtime = np.power(10, 0.8 * (d.subtract(d['9_15 m5'], axis=0)))
dtime
# Out:
#    7_15 m5  7_30 m5  9_15 m5  9_30 m5  13_15 m5  13_30 m5  18_15 m5  18_30 m5
# u    1.350    1.846      1.0    1.489     0.585     0.972     0.339     0.605
# g    1.120    1.233      1.0    1.157     0.773     0.988     0.552     0.787
# r    1.067    1.125      1.0    1.087     0.852     0.993     0.677     0.862
# i    1.047    1.086      1.0    1.060     0.891     0.995     0.747     0.899
# z    1.031    1.057      1.0    1.040     0.923     0.997     0.812     0.929
# y    1.026    1.046      1.0    1.033     0.936     0.997     0.840     0.940

# %% [markdown]
# Account for distribution of readnoise and filters:
# * 50% of the focal plane has 7e read noise
# * 25% of the focal plane has 9e read noise
# * 20% of the focal plane has 13e read noise
# * 5% of the focal plane has 18e read noise

# %%
# Change in time per band (2x15s visits)
dtime_weighted = (0.50 * dtime['7_15 m5']   + 0.25 * dtime['9_15 m5'] 
                  + 0.20 * dtime['13_15 m5'] + 0.05 * dtime['18_15 m5'])
dtime_weighted
# Out:
# u    1.059
# g    0.992
# r    0.988
# i    0.989
# z    0.991
# y    0.992
# dtype: float64

# %%
dtime_total = 0
for f in SRD_time_distribution:
    dtime_total += dtime_weighted[f] * SRD_time_distribution[f]
dtime_total
# Out:
# 0.9937374388568707

# %%
# Change in time per band (1x30s visits)
dtime_weighted = (0.50 * dtime['7_30 m5']   + 0.25 * dtime['9_30 m5'] 
                  + 0.20 * dtime['13_30 m5'] + 0.05 * dtime['18_30 m5'])
dtime_weighted
# Out:
# u    1.520
# g    1.143
# r    1.076
# i    1.052
# z    1.034
# y    1.028
# dtype: float64

# %%
dtime_total = 0
for f in SRD_time_distribution:
    dtime_total += dtime_weighted[f] * SRD_time_distribution[f]
dtime_total
# Out:
# 1.0887195197848876
